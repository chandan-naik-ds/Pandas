# %%
import pandas as pd
data = {
    'Student' : ["Chandan", "Ram", "Mahesh", "Ravi", "Tom"],
    'rank' : [1, 4, 3, 5, 2],
    'marks':[95, 70, 80, 60, 90]

}

res = pd.DataFrame(data)

print("Student Recordes \n",res)
# Out:
# Student Recordes
#     Student  rank  marks
# 0  Chandan     1     95
# 1  Vinayak     4     70
# 2   Nikhil     3     80
# 3     Ravi     5     60
# 4    Gowri     2     90
