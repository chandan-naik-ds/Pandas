# %%
import pandas as pd

# %%
df = pd.read_csv('Wheatherdata.csv')
df
# Out:
#           Day  Temperature  Windspeed climate
# 0  01-01-2017           32          6    Rain
# 1  01-02-2017           35          7   Sunny
# 2  01-03-2017           28          2    Snow
# 3  01-04-2017           24          7    Snow
# 4  01-05-2017           32          4    Rain
# 5  01-06-2017           32          2   Sunny

# %%
# df.shape

rows , columns = df.shape

# columns
rows
# Out:
# 6

# %%
df.head(1)

df.tail(1)
# Out:
#           Day  Temperature  Windspeed climate
# 5  01-06-2017           32          2   Sunny

# %%
df.columns
# Out:
# Index(['Day', 'Temperature', 'Windspeed', 'climate'], dtype='str')

# %%
df[2:5]
# Out:
#           Day  Temperature  Windspeed climate
# 2  01-03-2017           28          2    Snow
# 3  01-04-2017           24          7    Snow
# 4  01-05-2017           32          4    Rain

# %%
df.Temperature  # df.['Temperature]
# Out:
# 0    32
# 1    35
# 2    28
# 3    24
# 4    32
# 5    32
# Name: Temperature, dtype: int64

# %%
df[['Day', 'Temperature']]
# Out:
#           Day  Temperature
# 0  01-01-2017           32
# 1  01-02-2017           35
# 2  01-03-2017           28
# 3  01-04-2017           24
# 4  01-05-2017           32
# 5  01-06-2017           32

# %%
# type(df['Temperature'])
# Out:
# pandas.Series

# %%
df['Temperature'].mean()

float(df['Temperature'].mean())
# Out:
# 30.5
